# %%
#Importing necessary libraries
#import all packages in order
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 846E-B71A
#
#  Directory of C:\Users\USER\Desktop\Blossom Academy\PROJECT_1\FoodHub Project for Practice-20260226T150053Z-1-001\FoodHub Project for Practice
#
# 21/03/2026  15:46    <DIR>          .
# 26/02/2026  15:59    <DIR>          ..
# 05/03/2026  10:43    <DIR>          .ipynb_checkpoints
# 20/03/2026  11:10            18,073 FoodHub_Analysis.ipynb
# 21/03/2026  15:46           233,017 FoodHub_Analysis_1.ipynb
# 26/02/2026  15:59           123,933 foodhub_order.csv
# 26/02/2026  15:59            90,952 foodhub_order_v2.xlsx
#                4 File(s)        465,975 bytes
#                3 Dir(s)  138,838,364,160 bytes free

# %%
df = pd.read_csv('foodhub_order.csv')

# %% [markdown]
# # Data Overview

# %%
#viewing data
#df.sample
df.head()
# Out:
#    order_id  customer_id            restaurant_name cuisine_type  \
# 0   1477147       337525                    Hangawi       Korean
# 1   1477685       358141  Blue Ribbon Sushi Izakaya     Japanese
# 2   1477070        66393                Cafe Habana      Mexican
# 3   1477334       106968  Blue Ribbon Fried Chicken     American
# 4   1478249        76942           Dirty Bird to Go     American
#
#    cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 0              30.75         Weekend  Not given                     25
# 1              12.08         Weekend  Not given                     25
# 2              12.23         Weekday          5                     23
# 3              29.20         Weekend          3                     25
# 4              11.59         Weekday          4                     25
#
#    delivery_time
# 0             20
# 1             23
# 2             28
# 3             15
# 4             24

# %%
df.tail()
# Out:
#       order_id  customer_id                        restaurant_name  \
# 1893   1476701       292602  Chipotle Mexican Grill $1.99 Delivery
# 1894   1477421       397537                              The Smile
# 1895   1477819        35309                      Blue Ribbon Sushi
# 1896   1477513        64151                      Jack's Wife Freda
# 1897   1478056       120353                      Blue Ribbon Sushi
#
#        cuisine_type  cost_of_the_order day_of_the_week     rating  \
# 1893        Mexican              22.31         Weekend          5
# 1894       American              12.18         Weekend          5
# 1895       Japanese              25.22         Weekday  Not given
# 1896  Mediterranean              12.18         Weekday          5
# 1897       Japanese              19.45         Weekend  Not given
#
#       food_preparation_time  delivery_time
# 1893                     31             17
# 1894                     31             19
# ...

# %%
#checking for duplicates
# adding .sum() helps find the total duplicates
df.duplicated().sum()
print(f'The total number of duplicates in the dataset is zero({df.duplicated().sum()})')
# Out:
# The total number of duplicates in the dataset is zero(0)

# %%
#checking for data types
df.dtypes
# Out:
# order_id                   int64
# customer_id                int64
# restaurant_name           object
# cuisine_type              object
# cost_of_the_order        float64
# day_of_the_week           object
# rating                    object
# food_preparation_time      int64
# delivery_time              int64
# dtype: object

# %%
#check for missing values/null values

df.isnull().sum()
# Out:
# order_id                 0
# customer_id              0
# restaurant_name          0
# cuisine_type             0
# cost_of_the_order        0
# day_of_the_week          0
# rating                   0
# food_preparation_time    0
# delivery_time            0
# dtype: int64

# %%
df.shape
print(f'The total number of row is {df.shape[0]} and columns is {df.shape[1]}')
# Out:
# The total number of row is 1898 and columns is 9

# %%
df.describe()
# Out:
#            order_id    customer_id  cost_of_the_order  food_preparation_time  \
# count  1.898000e+03    1898.000000        1898.000000            1898.000000
# mean   1.477496e+06  171168.478398          16.498851              27.371970
# std    5.480497e+02  113698.139743           7.483812               4.632481
# min    1.476547e+06    1311.000000           4.470000              20.000000
# 25%    1.477021e+06   77787.750000          12.080000              23.000000
# 50%    1.477496e+06  128600.000000          14.140000              27.000000
# 75%    1.477970e+06  270525.000000          22.297500              31.000000
# max    1.478444e+06  405334.000000          35.410000              35.000000
#
#        delivery_time
# count    1898.000000
# mean       24.161749
# std         4.972637
# min        15.000000
# 25%        20.000000
# 50%        25.000000
# 75%        28.000000
# max        33.000000

# %%
df.columns.tolist()
# Out:
# ['order_id',
#  'customer_id',
#  'restaurant_name',
#  'cuisine_type',
#  'cost_of_the_order',
#  'day_of_the_week',
#  'rating',
#  'food_preparation_time',
#  'delivery_time']

# %% [markdown]
# # Order that are not rated

# %%
df.value_counts('rating')
#df.value_counts('rating').head()
df['rating'].value_counts()['Not given']
# Out:
# np.int64(736)

# %%
df.value_counts('rating')
# Out:
# rating
# Not given    736
# 5            588
# 4            386
# 3            188
# Name: count, dtype: int64

# %%
df.restaurant_name.unique()
# Out:
# array(['Hangawi', 'Blue Ribbon Sushi Izakaya', 'Cafe Habana',
#        'Blue Ribbon Fried Chicken', 'Dirty Bird to Go',
#        'Tamarind TriBeCa', 'The Meatball Shop', 'Barbounia',
#        'Anjappar Chettinad', 'Bukhara Grill',
#        'Big Wong Restaurant \x8c_¤¾Ñ¼', 'Empanada Mama (closed)', 'Pylos',
#        "Lucky's Famous Burgers", 'Shake Shack', 'Sushi of Gari',
#        'RedFarm Hudson', 'Blue Ribbon Sushi',
#        'Five Guys Burgers and Fries', 'Tortaria', 'Cafe Mogador',
#        'Otto Enoteca Pizzeria', 'Vezzo Thin Crust Pizza',
#        'Sushi of Gari 46', 'The Kati Roll Company', 'Klong',
#        '5 Napkin Burger', 'TAO', 'Parm', 'Sushi Samba',
#        'Haru Gramercy Park', 'Chipotle Mexican Grill $1.99 Delivery',
#        'RedFarm Broadway', 'Cafeteria', 'DuMont Burger',
#        "Sarabeth's East", 'Hill Country Fried Chicken', 'Bistango',
#        "Jack's Wife Freda", "Mamoun's Falafel", 'Prosperity Dumpling',
# ...

# %%
df.sample(9)
# Out:
#       order_id  customer_id             restaurant_name    cuisine_type  \
# 368    1477163       376578                 Shake Shack        American
# 699    1477160        61181           The Meatball Shop         Italian
# 1343   1477338        81110  Hill Country Fried Chicken        Southern
# 102    1477240       142356           Blue Ribbon Sushi        Japanese
# 1421   1477223       303548                 J. G. Melon        American
# 126    1478348       310051                        Parm         Italian
# 759    1476652       232035            ilili Restaurant  Middle Eastern
# 857    1476616       348096                        Parm         Italian
# 525    1476954        97370                      Momoya        Japanese
#
#       cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 368               15.76         Weekend          5                     32
# 699                8.63         Weekday          4                     28
# ...

# %%
df['restaurant_name'].nunique()
# Out:
# 178

# %%
# top 10 largest values
top_10 = df['restaurant_name'].value_counts().nlargest(10)
top_10 = top_10.sort_values(ascending = True)

# %%
top_10 = df['restaurant_name'].value_counts().nlargest(10)
top_10
# Out:
# restaurant_name
# Shake Shack                      219
# The Meatball Shop                132
# Blue Ribbon Sushi                119
# Blue Ribbon Fried Chicken         96
# Parm                              68
# RedFarm Broadway                  59
# RedFarm Hudson                    55
# TAO                               49
# Han Dynasty                       46
# Blue Ribbon Sushi Bar & Grill     44
# Name: count, dtype: int64

# %%
# top 10 largest values
top_10 = df['restaurant_name'].value_counts().nlargest(10)
top_10 = top_10.sort_values(ascending = True)

# %%
top_10.index
# Out:
# Index(['Blue Ribbon Sushi Bar & Grill', 'Han Dynasty', 'TAO', 'RedFarm Hudson',
#        'RedFarm Broadway', 'Parm', 'Blue Ribbon Fried Chicken',
#        'Blue Ribbon Sushi', 'The Meatball Shop', 'Shake Shack'],
#       dtype='object', name='restaurant_name')

# %%
top_10
# Out:
# restaurant_name
# Blue Ribbon Sushi Bar & Grill     44
# Han Dynasty                       46
# TAO                               49
# RedFarm Hudson                    55
# RedFarm Broadway                  59
# Parm                              68
# Blue Ribbon Fried Chicken         96
# Blue Ribbon Sushi                119
# The Meatball Shop                132
# Shake Shack                      219
# Name: count, dtype: int64

# %%
plt.barh(y= top_10.index,
        width = top_10.values)
plt.title('Top 10 most popular Restaurants');
#plt.tight

# %%
top_10.values
# Out:
# array([ 44,  46,  49,  55,  59,  68,  96, 119, 132, 219])

# %%
df['restaurant_name'].unique()
# Out:
# array(['Hangawi', 'Blue Ribbon Sushi Izakaya', 'Cafe Habana',
#        'Blue Ribbon Fried Chicken', 'Dirty Bird to Go',
#        'Tamarind TriBeCa', 'The Meatball Shop', 'Barbounia',
#        'Anjappar Chettinad', 'Bukhara Grill',
#        'Big Wong Restaurant \x8c_¤¾Ñ¼', 'Empanada Mama (closed)', 'Pylos',
#        "Lucky's Famous Burgers", 'Shake Shack', 'Sushi of Gari',
#        'RedFarm Hudson', 'Blue Ribbon Sushi',
#        'Five Guys Burgers and Fries', 'Tortaria', 'Cafe Mogador',
#        'Otto Enoteca Pizzeria', 'Vezzo Thin Crust Pizza',
#        'Sushi of Gari 46', 'The Kati Roll Company', 'Klong',
#        '5 Napkin Burger', 'TAO', 'Parm', 'Sushi Samba',
#        'Haru Gramercy Park', 'Chipotle Mexican Grill $1.99 Delivery',
#        'RedFarm Broadway', 'Cafeteria', 'DuMont Burger',
#        "Sarabeth's East", 'Hill Country Fried Chicken', 'Bistango',
#        "Jack's Wife Freda", "Mamoun's Falafel", 'Prosperity Dumpling',
# ...

# %% [markdown]
# # Plotting

# %%
sns.countplot(y=top_10)
# Out:
# <Axes: xlabel='count', ylabel='count'>

# %% [markdown]
# # Plotting a numerical variable

# %%
#choosing a numerical variable
df.head()
# Out:
#    order_id  customer_id            restaurant_name cuisine_type  \
# 0   1477147       337525                    Hangawi       Korean
# 1   1477685       358141  Blue Ribbon Sushi Izakaya     Japanese
# 2   1477070        66393                Cafe Habana      Mexican
# 3   1477334       106968  Blue Ribbon Fried Chicken     American
# 4   1478249        76942           Dirty Bird to Go     American
#
#    cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 0              30.75         Weekend  Not given                     25
# 1              12.08         Weekend  Not given                     25
# 2              12.23         Weekday          5                     23
# 3              29.20         Weekend          3                     25
# 4              11.59         Weekday          4                     25
#
#    delivery_time
# 0             20
# 1             23
# 2             28
# 3             15
# 4             24

# %%
sns.histplot(data = df, x = 'cost_of_the_order',kde = True);

# %%
sns.histplot(data=df,
            x = 'food_preparation_time');

# %%
#sns.countplot(
  #  data = df,
   # y = ''

# %%
sns.histplot(data = df, x = 'delivery_time',kde = True);

# %%
sns.boxplot(data = df, x = 'delivery_time');

# %%
sns.countplot(data=df,
    x='rating',
    order=df['rating'].value_counts().sort_values().index
);

# %%
sns.countplot(data=df,x = 'day_of_the_week');

# %% [markdown]
# # most poppular cuisine on the weekend

# %%
pop_cuisine_weekend = df[df['day_of_the_week'] == 'Weekend']['cuisine_type'].value_counts().head(1)
pop_cuisine_weekend
# Out:
# cuisine_type
# American    415
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    order_id  customer_id            restaurant_name cuisine_type  \
# 0   1477147       337525                    Hangawi       Korean
# 1   1477685       358141  Blue Ribbon Sushi Izakaya     Japanese
# 2   1477070        66393                Cafe Habana      Mexican
# 3   1477334       106968  Blue Ribbon Fried Chicken     American
# 4   1478249        76942           Dirty Bird to Go     American
#
#    cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 0              30.75         Weekend  Not given                     25
# 1              12.08         Weekend  Not given                     25
# 2              12.23         Weekday          5                     23
# 3              29.20         Weekend          3                     25
# 4              11.59         Weekday          4                     25
#
#    delivery_time
# 0             20
# 1             23
# 2             28
# 3             15
# 4             24

# %%
top_10 = df['restaurant_name'].value_counts().nlargest(10)

# %%
top_3_cust = df['customer_id'].value_counts().nlargest(3)
top_3_cust
# Out:
# customer_id
# 52832    13
# 47440    10
# 83287     9
# Name: count, dtype: int64

# %% [raw]
# What percentage of the orders cost more than 20 dollars?

# %%
orders_above20 = df[df['cost_of_the_order']>20].shape[0]
orders_above20
# Out:
# 555

# %%
total_orders = df.shape[0]

percentage_above = (orders_above20/total_orders)*100
percentage_above
# Out:
# 29.24130663856691

# %%
avegera_deltime = df['delivery_time'].mean().round(2)
avegera_deltime
# Out:
# np.float64(24.16)

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data=df, x='cuisine_type',y='cost_of_the_order')
plt.xticks(rotation=45)
plt.title('cuisine_type vs cost_of_the_order')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data=df, x='rating',y='cost_of_the_order')
plt.xticks(rotation=45)
plt.title('rating vs cost_of_the_order')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data=df, x='cuisine_type',y='food_preparation_time')
plt.xticks(rotation=45)
plt.title('cuisine_type vs food_preparation_time')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data=df, x='day_of_the_week',y='delivery_time')
plt.xticks(rotation=45)
plt.title('day_of_the_week vs delivery_time')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data=df, x='food_preparation_time',y='day_of_the_week')
plt.xticks(rotation=45)
plt.title('food_preparation_time vs day_of_the_week')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.heatmap(df[['cost_of_the_order','food_preparation_time','delivery_time']].corr(),annot=True,cmap='YlGnBu')
plt.title('Correlation Heatmap')
plt.show()

# %%
df['rating'] = df['rating'].replace('Not given', np.nan)
df['rating'] = pd.to_numeric(df['rating'])

# %%
rest_ratings = df.groupby('')

# %%
qualified_rest=restuarant

# %%
#df.groupby(['cuisine_type','day_of_the_week'],as_index  = False)['order_id'].count()\
    .rename(columns = {'order_id':'counts'})\.sort_values


#df_cuisiine

# %%
#for i in df_cuisiine:
   # print(i)

# %% [markdown]
# # Percentage of order cost more than 20 dollars
